# %%
import YummyHub

# %%
YummyHub.main()
# Out:
# WELCOME TO THE DIGITAL RECIPE BOOK
# This application helps you easily store, retrieve, and
# manage your favorite cooking recipes all in one place.
#
# === DIGITAL RECIPE BOOK ===
# 1. Add a new recipe
# 2. Search for a recipe by ingredient
# 3. View all recipes
# 4. Generate a random recipe
# 5. Rating recipes
# 6. Sort by rating
# 7. Generate a shopping list
# 8. Exit
# Enter your choice (1-8):  1
# === Add a New Recipe ===
# Enter recipe name:  tea
# tea already exists, please add another recipe
# Enter recipe name:  karak
# Please enter ingredients below (separated by commas OR one by one), then type 'done' when finished:
# Add ingredient(s):  water
# Add ingredient(s):  tea
# Add ingredient(s):  rainbow milk
# Add ingredient(s):  done
# Enter preparation time in minutes:  15
# Please enter cooking instructions step-by-step. Type 'done' when finished:
# Step 1:  boil the water
# Step 2:  add add tea
# Step 3:  add the milk
# Step 4:  done
# ...
